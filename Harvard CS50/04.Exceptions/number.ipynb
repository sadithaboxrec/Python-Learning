# %% [markdown]
# ##### Syntax errors cannot solved without fixing the errors

# %% [markdown]
# ### Value Error

# %%
#input=Dog

x=int(input("Enter the X"))
print(f"X is {x}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 #input=Dog
# ----> 3 x=int(input("Enter the X"))
#       4 print(f"X is {x}")
#
# ValueError: invalid literal for int() with base 10: 'Dog'

# %%
#input - Dog

try:
    x=int(input("Enter the X"))
    print(f"X is {x}")
except ValueError:
    print("you did not enter an Integer")
# Out:
# you did not enter an Integer

# %%
#input - Dog

try:
    x=int(input("Enter the X"))
except ValueError:
    print("you did not enter an Integer")

print(f"X is {x}")
# Out:
# you did not enter an Integer
# X is 2

# %% [markdown]
# ###### X is unable to pick "Dog" as a input so this going to be an error

# %%
#input - Dog

try:
    x=int(input("Enter the X"))
except ValueError:
    print("you did not enter an Integer")
else:
    print(f"X is {x}")
# Out:
# you did not enter an Integer

# %%
#input - Dog , Dog,5

while True:

    try:
        x=int(input("Enter the X"))
    except ValueError:
        print("you did not enter an Integer")
    else:
        break

print(f"X is {x}")
# Out:
# you did not enter an Integer
# you did not enter an Integer
# X is 5

# %%
#input - Dog , Dog,5

while True:

    try:
        x=int(input("Enter the X"))
        break
    except ValueError:
        print("you did not enter an Integer")


print(f"X is {x}")
# Out:
# you did not enter an Integer
# you did not enter an Integer
# X is 5

# %%
#input - Dog , Dog,7

def main():
    x=get_int()
    print(f"X is {x}")

def get_int():
    while True:
        try:
            x=int(input("Enter the X"))
        except ValueError:
            print("you did not enter an Integer")
        else:
            break
    return x

main()
# Out:
# you did not enter an Integer
# you did not enter an Integer
# X is 7

# %%
#input - Dog , Dog,7

def main():
    x=get_int()
    print(f"X is {x}")

def get_int():
    while True:
        try:
            x=int(input("Enter the X"))
        except ValueError:
            print("you did not enter an Integer")
        else:
            return x
# Removing break and adding more powerful return
main()

# %%
#input - Dog , Dog,7

def main():
    x=get_int()
    print(f"X is {x}")

def get_int():
    while True:
        try:
            return int(input("Enter the X"))
        except ValueError:
            print("you did not enter an Integer")
# Removing break and adding more powerful return
main()

# %% [markdown]
# ### when want to catch a exception but not to do anything about that :PASS

# %%
#input - Dog , Dog,7

def main():
    x=get_int()
    print(f"X is {x}")

def get_int():
    while True:
        try:
            return int(input("Enter the X"))
        except ValueError:
            pass
# Removing break and adding more powerful return
main()
# Out:
# X is 7

# %% [markdown]
# ###### Not printing exception msgs just ignore them

# %%
#input - Dog , Dog,7

def main():
    x=get_int("Enter the X")
    print(f"X is {x}")

def get_int(prompt):
    while True:
        try:
            return int(input(prompt))
        except ValueError:
            pass
# Removing break and adding more powerful return
main()
# Out:
# X is 7
