# %%
name=input("Enter your name: ")
house=input("Enter your house: ")

print(f"{name} is from {house}")
# Out:
# Ron is from Gryffindor

# %%
def main():
    name=get_name()
    house=get_house()
    print(f"{name} is from {house}")

def get_name():
    return input("Enter your name: ")

def get_house():
    return input("Enter your house: ")

if __name__=="__main__":
    main()
# Out:
# Harry is from Gryffindor

# %%
def main():
    student=get_student()
    print(f"{student}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return f"{name} is from {house}"

main()


# Return value: ONE string

# Structure: Simple, but less flexible (you can’t separately use the name or house later)
# Out:
# Ron is from Gryffindor

# %%
def main():
    name,house=get_student()
    print(f"{name} is from {house}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return name, house

    # We return one value which has two values inside

main()

""""
get_student() returns TWO separate values (a tuple):
("Harry", "Gryffindor")

In main(), Python unpacks those values into:

name

house

You print them in the format you want.

📌 Summary

Return value: TWO separate pieces of data

Structure: More flexible (you can use name and house independently)

"""
# Out:
# Ron is from Gryfffindor

# %%
def main():
    student=get_student()
    print(f"{student[0]} is from {student[1]}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return (name, house)


main()
# Out:
# Hermione is from Gryffindor

# %%
# input =Padma, Gryffindor

def main():
    student=get_student()
    if student[0] == "Padma":
        student[1]="Ravenclaw"
    print(f"{student[0]} is from {student[1]}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return (name, house)


main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      11     house=input("Enter your house: ")
#      12     return (name, house)
# ---> 15 main()
#
# Cell In[4], line 6, in main()
#       4 student=get_student()
#       5 if student[0] == "Padma":
# ----> 6     student[1]="Ravenclaw"
#       7 print(f"{student[0]} is from {student[1]}")
#
# TypeError: 'tuple' object does not support item assignment

# %%
# input =Padma, Gryffindor
# due to the return list unlike tuple , we can correct the data

def main():
    student=get_student()
    if student[0] == "Padma":
        student[1]="Ravenclaw"
    print(f"{student[0]} is from {student[1]}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return [name, house]


main()
# Out:
# Padma is from Ravenclaw

# %% [markdown]
# ##### using DICT

# %%
# input =Padma, Ravenclaw

def main():
    student=get_student()
    print(f"{student['name']} is from {student['house']}")

def get_student():
    student={}
    student["name"]=input("Enter your name: ")
    student["house"]=input("Enter your house: ")
    return student


main()
# Out:
# Padma is from Ravenclaw

# %%
#alternative way

# input =Padma, Gryffindor

def main():
    student=get_student()
    if student["name"] == "Padma":
        student["house"]="Ravenclaw"
    print(f"{student['name']} is from {student['house']}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    return {"name":name, "house":house}


main()
# Out:
# Padma is from Ravenclaw
