# %% [markdown]
# ## Class Methods

# %%
import random

class Hat:

    def __init__(self):
        self.houses = ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]

    def sort(self,name):
        print(name ,"is in", random.choice(self.houses))


hat = Hat()
hat.sort("Harry")
# Out:
# Harry is in Slytherin

# %%
import random

class Hat:

    def __init__(self):
        self.houses = ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]

    def sort(self,name):
        print(name ,"is in", random.choice(self.houses))


hat = Hat()
hat2 = Hat()
hat.sort("Harry")
hat2.sort("Ron")
# Out:
# Harry is in Slytherin
# Ron is in Hufflepuff

# %% [markdown]
# #### up until now we used instance methods.
#
# #### Writing functions inside the classes that are automatically passed a references to cells, current cells.

# %% [markdown]
# # @classmethods

# %%
import random

class Hat:

    houses = ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]

    @classmethod
    def sort(cls,name):
        print(name ,"is in", random.choice(cls.houses))

Hat.sort("Harry")
# Out:
# Harry is in Gryffindor

# %% [markdown]
# ##### That means you don’t need to create a Hat() object — you call the method directly on the class (Hat.sort("Harry")).
#
#
# #### houses = ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]
#
# This variable belongs to the class, not to any instance.
# All Hat objects (if you made any) would share the same list of houses.
# You access it using cls.houses inside class methods.
#
# @classmethod tells Python that this method works on the class, not an individual object.
#
# The first parameter is cls (class), not self (instance).
#
# Since the houses list is a class variable, this method can access it using cls.houses.
