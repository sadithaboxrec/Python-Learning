# %%
# input = Neville,Gryffindor

class Student:
    ...

def main():
    student=get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    student=Student()
    student.name=input("Enter your name: ")
    student.house=input("Enter your house: ")
    return student


main()
# Out:
# Nevill from Gryffindor

# %% [markdown]
#  ##### __ called as dunder
#
# ###       __init__(self)   - is instance method

# %%
# input = Neville,Gryffindor

class Student:
    def __init__(self,name,house):
        self.name=name   # instance variables
        self.house=house

def main():
    student=get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    student=Student(name,house)
    return student

main()
# Out:
# Neville from Gryffindor

# %% [markdown]
# #### OOP more encourage to encapsulate inside of a class , all functionalities related to the class.

# %%
# input = Neville,Gryffindor

class Student:
    def __init__(self,name,house):

        if not name:
            raise ValueError("Student name cannot be empty")
        if  house not in ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]:
            raise ValueError("Student house not correct")

        self.name=name   # instance variables
        self.house=house

def main():
    student=get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")

    student=Student(name,house)
    return student

main()
# Out:
# Neville from Gryffindor

# %%
# input = Neville,Gryffindor

class Student:
    def __init__(self,name,house):

        if not name:
            raise ValueError("Student name cannot be empty")
        if  house not in ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]:
            raise ValueError("Student house not correct")

        self.name=name   # instance variables
        self.house=house

    def __str__(self):
        return f"{self.name} from {self.house}"

def main():
    student=get_student()
    print(student)

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")

    student=Student(name,house)
    return student

main()
# Out:
# Neville from Gryffindor

# %%
# input = Neville,Gryffindor

class Student:
    def __init__(self,name,house,patronous):

        if not name:
            raise ValueError("Student name cannot be empty")
        if  house not in ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]:
            raise ValueError("Student house not correct")

        self.name=name   # instance variables
        self.house=house
        self.patronous=patronous

    def __str__(self):
        return f"{self.name} from {self.house}. His patronous is {self.patronous}."

def main():
    student=get_student()
    print(student)

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    patronous=input("Enter your patronous: ")

    student=Student(name,house,patronous)
    return student

main()
# Out:
# nEVILLE from Gryffindor. His patronous is Bot.

# %% [markdown]
# #### classes can have functions which called as methods in classes

# %%
# input = Hermione,Gryffindor,Otter

class Student:
    def __init__(self,name,house,patronous):

        if not name:
            raise ValueError("Student name cannot be empty")
        if  house not in ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]:
            raise ValueError("Student house not correct")

        self.name=name   # instance variables
        self.house=house
        self.patronous=patronous

    def __str__(self):   # take self by default
        return f"{self.name} from {self.house}."

    def charm(self):
        match self.patronous:
            case "Stag":
                return "🦌"
            case "Otter":
                return "🦦"
            case "Jack Russel":
                return "🐕"
            case _:
                return "🪄"

def main():
    student=get_student()
    print("Expecto Patronum!")
    print(student)
    print(student.charm())

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")
    patronous=input("Enter your patronous: ")

    student=Student(name,house,patronous)
    return student

main()
# Out:
# Expecto Patronum!
# Hermione from Gryffindor.
# 🦦

# %% [markdown]
# ####  __str__(self) (String Representation):
#
#  #####   This method defines how the object should be represented as a string (e.g., when passed to print()).
#
#  #####   It returns a formatted string: f"{self.name} from {self.house}.".

# %%
# input = Hermione,Gryffindor

class Student:
    def __init__(self,name,house):

        if not name:
            raise ValueError("Student name cannot be empty")
        if  house not in ["Gryffindor","Hufflepuff","Ravenclaw","Slytherin"]:
            raise ValueError("Student house not correct")

        self.name=name   # instance variables
        self.house=house


    def __str__(self):
        return f"{self.name} from {self.house}."


def main():
    student=get_student()
    student.house="Privet Drive"
    print(student)

def get_student():
    name=input("Enter your name: ")
    house=input("Enter your house: ")

    student=Student(name,house)
    return student

main()
# Out:
# Hermione from Privet Drive.

# %% [markdown]
# ##### House changes to Privet drive and no error raising

# %% [markdown]
# ### student.house="Privet Drive"     can still access them using object
#
# ### even though classes offer more control in data we stroring it doesn't prevent from user messing with data.
#
# ### No longer those error handling gonna valid either
