# %%
print(type(20))
# Out:
# <class 'int'>

# %%
print(type("Hello World"))
# Out:
# <class 'str'>

# %%
print(type([]))
# Out:
# <class 'list'>

# %%
print(type({}))
# Out:
# <class 'dict'>

# %%
print(type(list()))
# Out:
# <class 'list'>

# %% [markdown]
# #### Conventions
#
# ##### int,str,list all come with python,they decided to use them as built in data types.  classes are lower cases
#
# #### when we create classes it should start with Upper cases
