# %%
print("#")
print("#")
print("#")
# Out:
# #
# #
# #

# %%
for _ in range(3):
    print("#")
# Out:
# #
# #
# #

# %%
def main():
    print_column(3)

def print_column(column):
    for _ in range(column):
        print("#")

main()
# Out:
# #
# #
# #

# %%
def main():
    print_column(3)

def print_column(column):
    print("#\n" * column,end="")

main()
# Out:
# #
# #
# #

# %%
def main():
    print_row(4)

def print_row(width):
    print("?" * width)

main()
# Out:
# ????

# %%
def main():
    print_square(3)

def print_square(size):
    # For each row in square
    for i in range(size):
        #  brick in row
        for j in range(size):
            print("#",end="")

        print()

main()
# Out:
# ###
# ###
# ###
