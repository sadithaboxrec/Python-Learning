# %% [markdown]
# #### API-Application Programming Interface

# %%
# !pip install kaggle
# Out:
# ...
#
#    ---------- -----------------------------  3/11 [python-dotenv]
#    -------------- -------------------------  4/11 [protobuf]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    --------------------- ------------------  6/11 [markdown-it-py]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ------------------------- --------------  7/11 [kagglesdk]
#    ----------------------------- ----------  8/11 [mdit-py-plugins]
#    -------------------------------- -------  9/11 [jupytext]
#    -------------------------------- -------  9/11 [jupytext]
#    ------------------------------------ --- 10/11 [kaggle]
#    ---------------------------------------- 11/11 [kaggle]
#
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
