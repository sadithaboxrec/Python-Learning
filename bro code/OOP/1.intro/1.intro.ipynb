# %% [markdown]
# object = A "bundle" of related attributes (variables) and methods (functions)
#
#             Ex. phone, cup, book
#             You need a "class" to create many objects
#
# class  = (blueprint) used to design the structure and layout of an object

# %%
class Cars:

     # dunder -double underscore

    def __init__(self,model,year,color,for_sale):
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale

car1=Cars('BMW',2022,'blue',False)

print(car1)  # memory address of car object

print(car1.model)
print(car1.year)   # . known as attribute access operator
print(car1.color)
print(car1.for_sale)
# Out:
# ...
# BMW
# 2022
# blue
# False

# %%
class Cars:

     # dunder -double underscore

    def __init__(self,model,year,color,for_sale):
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale

car1=Cars('BMW',2022,'blue',False)
car2=Cars('Toyota',2025,'blue',True)



print(car1.model)
print(car1.year)   # . known as attribute access operator
print(car1.color)
print(car1.for_sale)
print()
print(car2.model)
print(car2.year)
print(car2.color)
print(car2.for_sale)
# Out:
# ...
# BMW
# 2022
# blue
# False
#
# Toyota
# 2025
# blue
# True

# %% [markdown]
# ### Fot better placement we can put them in new python file

# %%
class Cars:

     # dunder -double underscore

    def __init__(self,model,year,color,for_sale):
        self.model = model
        self.year = year
        self.color = color
        self.for_sale = for_sale

car1=Cars('BMW',2022,'blue',False)
car2=Cars('Toyota',2025,'blue',True)



print(car1.model)
print(car1.year)   # . known as attribute access operator
print(car1.color)
print(car1.for_sale)
print()
print(car2.model)
print(car2.year)
print(car2.color)
print(car2.for_sale)
